# %%
# %pip install datasets ipywidgets huggingface_hub --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import whoami

whoami()
# Out:
# {'type': 'user',
#  'id': '68d7376d93e1d0068e1d556a',
#  'name': 'PLKhang',
#  'fullname': 'Khang Le Phuc',
#  'isPro': False,
#  'avatarUrl': 'https://cdn-avatars.huggingface.co/v1/production/uploads/68d7376d93e1d0068e1d556a/W17x_yGGmQL5QSQmYZ-WY.jpeg',
#  'orgs': [],
#  'auth': {'type': 'access_token',
#   'accessToken': {'displayName': 'kaggle1',
#    'role': 'fineGrained',
#    'createdAt': '2025-12-14T00:15:28.482Z',
#    'fineGrained': {'canReadGatedRepos': True,
#     'global': [],
#     'scoped': [{'entity': {'_id': '664dc170474f2283fa5c8659',
#        'type': 'model',
#        'name': 'mistralai/Mistral-7B-Instruct-v0.3'},
#       'permissions': ['repo.content.read', 'discussion.write', 'repo.write']},
#      {'entity': {'_id': '6698d8a0653e4babe21e1e7d',
#        'type': 'model',
#        'name': 'meta-llama/Llama-3.1-8B-Instruct'},
#       'permissions': ['repo.content.read', 'discussion.write', 'repo.write']},
#      {'entity': {'_id': '68d7376d93e1d0068e1d556a',
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files=r"..\..\storage\data\finetuning_dataset_prompts.json")
dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['prompt'],
#         num_rows: 1797
#     })
# })

# %%
huggingface_user = "PLKhang"
dataset_name = "report-finetuning-prompts"   # tên dataset

repo_id = f"{huggingface_user}/{dataset_name}"

# # Push dataset lên HF Hub
dataset.push_to_hub(repo_id)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/275 [00:00<?, ?B/s]
# c:\Users\pkstr\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\pkstr\.cache\huggingface\hub\datasets--PLKhang--report-finetuning-prompts. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
from datasets import load_dataset

dataset = load_dataset(f"{huggingface_user}/{dataset_name}")
print(dataset)
print(dataset["train"][5])
# Out:
# README.md:   0%|          | 0.00/275 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/511k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1797 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['prompt'],
#         num_rows: 1797
#     })
# })
# ...
